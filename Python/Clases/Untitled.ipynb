# %%
#codigo de un constructor de pantalla de inicio de un juego
personajes={
    "raza":{
        "humanos":{
            "clase":{
                "guerreros":{
                    "stats":{
                        "vida":"1200",
                        "mana":"850"
                    }
                },
                "cazador":{
                    "stats":{
                        "vida":"800",
                        "mana":"900"
                    }
                },
                "druida":{
                    "stats":{
                        "vida":"1000",
                        "mana":"900"
                    }
                }
            }
        },
        "orcos":{
            "clase":{
                "guerreros":{
                    "stats":{
                        "vida":"1200",
                        "mana":"850"
                    }
                },
                "cazador":{
                    "stats":{
                        "vida":"800",
                        "mana":"900"
                    }
                },
                "chamam":{
                    "stats":{
                        "vida":"1000",
                        "mana":"900"
                    }   
                }
            }
        }
    }
}
import uuid
import json
import time

class personaje():
    
    def __init__(self,nombre,raza,clase,vida,mana):
        self.nombre=nombre
        self.raza=raza
        self.clase=clase
        self.vida=vida
        self.mana=mana
    def configurar_personaje(self):
        print("Que raza quieres ser?:\n 1. Humanos \n 2.Orcos")
        raza=input("\n")
        if raza=="1" or raza=="humanos":
            raza="humanos"
            print("Que clase quieres ser?:\n 1. guerrero \n 2.cazador \n 3.druida")
            clase=input("\n")
            
            if clase=="1" or raza=="guerrero":
                clase="guerrero"
                #aqui tenemos que llamar  un metodo que cree al personaje
            elif clase=="2" or raza=="cazador":
                clase="cazador"
                #aqui tenemos que llamar  un metodo que cree al personaje
            elif clase=="3" or raza=="druida":
                clase="druida"
                #aqui tenemos que llamar  un metodo que cree al personaje
            else:
                print("Clase no valida")
                #control de errores
        elif raza=="2" or raza=="orcos":
            raza="orcos"
            print("Que clase quieres ser?:\n 1. guerrero \n 2.cazador \n 3.chaman")
            clase=input("\n")
            
            if clase=="1" or raza=="guerrero":
                clase="guerrero"
                #aqui llamamos  un metodo que cree al personaje
                self.crear_personaje(raza,clase)
            elif clase=="2" or raza=="cazador":
                clase="cazador"
                #aqui llamamos  un metodo que cree al personaje
                self.crear_personaje(raza,clase)
            elif clase=="3" or raza=="chaman":
                clase="chaman"
                #aqui llamamos  un metodo que cree al personaje
                self.crear_personaje(raza,clase)
            else:
                print("Clase no valida")
                #control de errores
        else:
            print("Raza no valida")
                #control de errores
    def crear_personaje(self,raza,clase):
        vida=personajes["raza"][raza]["clase"][clase]["stats"]["vida"]
        mana=personajes["raza"][raza]["clase"][clase]["stats"]["mana"]
        
        nombre=input("Adalid, como deseas ser llamado:\n")
        #llamo al constructor
        nuevo_pj=personaje(self,nombre=nombre,raza=raza,clase=clase,mana=mana)
        #creo un diccionario para guardar la info del pj
        datos={
            "id":str(uuuid.uuid1()),
            "nombre":nuevo_pj.nombre,
            "raza":nuevo_pj.raza,
            "clase":nuevo_pj.clase,
            "vida":nuevo_pj.vida,
            "mana":nuevo_pj.mana
        }
        
        #aqui temos que llamar un metodo para guardar al personaje
        print("El personaje {} ha sido creado y guardado satisfactoriamente".format(nuevo_pj.nombre))
